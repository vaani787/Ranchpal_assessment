# %%
from datetime import datetime
import pandas as pd
import numpy as np

# %% [markdown]
# # Import .csv file

# %%
df=pd.read_csv('sample-data.csv')

# %%
df.head(5)
# Out:
#          time      accX      accY      accZ       gyrX       gyrY       gyrZ  \
# 0  1620022010 -5.509766 -2.220703  5.208984   3.417969  16.113281 -30.944824
# 1  1620022010 -5.533203 -2.210938  5.205078 -15.380859  22.277832 -27.893066
# 2  1620022010 -5.591797 -2.097656  5.251953 -28.564453  27.282715 -22.155762
# 3  1620022011 -5.517578 -2.107422  5.220703 -43.029785  37.841797  -6.103516
# 4  1620022011 -5.562500 -2.152344  5.306641 -57.617188  41.503906  12.451172
#
#        magX      magY      magZ
# 0 -0.175195  0.006348  0.060303
# 1 -0.175195  0.006348  0.060303
# 2 -0.175195  0.006348  0.060303
# 3 -0.175195  0.006348  0.060303
# 4 -0.175195  0.006348  0.060303

# %% [markdown]
# # Task 1

# %%
print(datetime.now())
# Out:
# 2021-06-02 12:37:38.891663

# %%
df['time']=datetime.now()

# %%
df.head(5)
# Out:
#                         time      accX      accY      accZ       gyrX  \
# 0 2021-06-02 12:37:39.197938 -5.509766 -2.220703  5.208984   3.417969
# 1 2021-06-02 12:37:39.197938 -5.533203 -2.210938  5.205078 -15.380859
# 2 2021-06-02 12:37:39.197938 -5.591797 -2.097656  5.251953 -28.564453
# 3 2021-06-02 12:37:39.197938 -5.517578 -2.107422  5.220703 -43.029785
# 4 2021-06-02 12:37:39.197938 -5.562500 -2.152344  5.306641 -57.617188
#
#         gyrY       gyrZ      magX      magY      magZ
# 0  16.113281 -30.944824 -0.175195  0.006348  0.060303
# 1  22.277832 -27.893066 -0.175195  0.006348  0.060303
# 2  27.282715 -22.155762 -0.175195  0.006348  0.060303
# 3  37.841797  -6.103516 -0.175195  0.006348  0.060303
# 4  41.503906  12.451172 -0.175195  0.006348  0.060303

# %% [markdown]
# # Task 2

# %%
df['labels']=np.nan

# %%
def put_label(label,start,end):
    df['labels'][start:end+1]=label
    print(df)

# %%
put_label(2,2,7)
# Out:
#                             time      accX      accY      accZ       gyrX  \
# 0     2021-06-02 12:37:39.197938 -5.509766 -2.220703  5.208984   3.417969
# 1     2021-06-02 12:37:39.197938 -5.533203 -2.210938  5.205078 -15.380859
# 2     2021-06-02 12:37:39.197938 -5.591797 -2.097656  5.251953 -28.564453
# 3     2021-06-02 12:37:39.197938 -5.517578 -2.107422  5.220703 -43.029785
# 4     2021-06-02 12:37:39.197938 -5.562500 -2.152344  5.306641 -57.617188
# 5     2021-06-02 12:37:39.197938 -5.582031 -2.158203  5.263672 -62.561035
# 6     2021-06-02 12:37:39.197938 -5.574219 -2.148438  5.269531 -77.941894
# 7     2021-06-02 12:37:39.197938 -5.558594 -2.216797  5.332031 -80.444336
# 8     2021-06-02 12:37:39.197938 -5.482422 -2.220703  5.378906 -74.218750
# 9     2021-06-02 12:37:39.197938 -5.458984 -2.220703  5.402344 -69.274902
# 10    2021-06-02 12:37:39.197938 -5.457031 -2.234375  5.373047 -55.236816
# 11    2021-06-02 12:37:39.197938 -5.484375 -2.232422  5.427734 -45.471191
# ...
